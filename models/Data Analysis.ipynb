# %%
import pandas as pd

# Load your Excel sheet into a DataFrame
excel_file_path = "E:\Downloads\ProdData.xlsx"
df = pd.read_excel(excel_file_path)

# Group by Category and aggregate by quantity and net amount
category_stats = df.groupby('MAIN CATEGORY').agg({'Qty': 'sum', 'Item Net Amount': 'sum'})

# Find the top and least selling category by quantity and value
top_category_by_quantity = category_stats['Qty'].idxmax()
least_category_by_quantity = category_stats['Qty'].idxmin()
top_category_by_value = category_stats['Item Net Amount'].idxmax()
least_category_by_value = category_stats['Item Net Amount'].idxmin()

# Group by Subcategory and aggregate by quantity and net amount
subcategory_stats = df.groupby('SUB CATEGORY').agg({'Qty': 'sum', 'Item Net Amount': 'sum'})

# Find the top and least selling subcategory by quantity and value
top_subcategory_by_quantity = subcategory_stats['Qty'].idxmax()
least_subcategory_by_quantity = subcategory_stats['Qty'].idxmin()
top_subcategory_by_value = subcategory_stats['Item Net Amount'].idxmax()
least_subcategory_by_value = subcategory_stats['Item Net Amount'].idxmin()

# Group by Brand and aggregate by quantity and net amount
brand_stats = df.groupby('BRAND').agg({'Qty': 'sum', 'Item Net Amount': 'sum'})

# Find the top and least selling brand by quantity and value
top_brand_by_quantity = brand_stats['Qty'].idxmax()
least_brand_by_quantity = brand_stats['Qty'].idxmin()
top_brand_by_value = brand_stats['Item Net Amount'].idxmax()
least_brand_by_value = brand_stats['Item Net Amount'].idxmin()

# Group by Item Name and aggregate by quantity and net amount
item_stats = df.groupby('Item Name').agg({'Qty': 'sum', 'Item Net Amount': 'sum'})

# Find the top and least selling item by quantity and value
top_item_by_quantity = item_stats['Qty'].idxmax()
least_item_by_quantity = item_stats['Qty'].idxmin()
top_item_by_value = item_stats['Item Net Amount'].idxmax()
least_item_by_value = item_stats['Item Net Amount'].idxmin()

# Print the results
print("Top selling category by quantity:", top_category_by_quantity)
print("Least selling category by quantity:", least_category_by_quantity)
print("\nTop selling category by value:", top_category_by_value)
print("Least selling category by value:", least_category_by_value)
print("\n\nTop selling subcategory by quantity:", top_subcategory_by_quantity)
print("Least selling subcategory by quantity:", least_subcategory_by_quantity)
print("\nTop selling subcategory by value:", top_subcategory_by_value)
print("Least selling subcategory by value:", least_subcategory_by_value)
print("\n\nTop selling brand by quantity:", top_brand_by_quantity)
print("Least selling brand by quantity:", least_brand_by_quantity)
print("\nTop selling brand by value:", top_brand_by_value)
print("Least selling brand by value:", least_brand_by_value)
print("\n\nTop selling item by quantity:", top_item_by_quantity)
print("Least selling item by quantity:", least_item_by_quantity)
print("\nTop selling item by value:", top_item_by_value)
print("Least selling item by value:", least_item_by_value)
# Out:
# Top selling category by quantity: TRISHIKA GROCERY
# Least selling category by quantity: BAGS&PURSES
#
# Top selling category by value: TRISHIKA GROCERY
# Least selling category by value: CARRY BAG
#
#
# Top selling subcategory by quantity: BISCUITS & COOKIES
# Least selling subcategory by quantity: BABY FEEDER
#
# Top selling subcategory by value: COOKING OIL
# Least selling subcategory by value: PENCIL
#
#
# Top selling brand by quantity: BRITANIA
# Least selling brand by quantity: 24MANTRA
#
# Top selling brand by value: TRISHIKA
# Least selling brand by value: RIN
#
#
# Top selling item by quantity: 7 STAR RICE BULK
# Least selling item by quantity: 1 BOX M5 MONTEX
#
# Top selling item by value: ASHIRVAD ATTA 5KG
# Least selling item by value: LINC ACE FINE POINT BLUE

# %%
import pandas as pd

# Load your Excel sheet into a DataFrame
excel_file_path = "E:\Downloads\ProdData.xlsx"
df = pd.read_excel(excel_file_path)

# Group by Category and aggregate by quantity and net amount
category_stats = df.groupby('MAIN CATEGORY').agg({'Qty': 'sum', 'Item Net Amount': 'sum'})

# Find the top and least selling category by quantity and value
top_categories_by_quantity = category_stats.nlargest(5, 'Qty')
least_categories_by_quantity = category_stats.nsmallest(5, 'Qty')
top_categories_by_value = category_stats.nlargest(5, 'Item Net Amount')
least_categories_by_value = category_stats.nsmallest(5, 'Item Net Amount')

# Group by Subcategory and aggregate by quantity and net amount
subcategory_stats = df.groupby('SUB CATEGORY').agg({'Qty': 'sum', 'Item Net Amount': 'sum'})

# Find the top and least selling subcategory by quantity and value
top_subcategories_by_quantity = subcategory_stats.nlargest(5, 'Qty')
least_subcategories_by_quantity = subcategory_stats.nsmallest(5, 'Qty')
top_subcategories_by_value = subcategory_stats.nlargest(5, 'Item Net Amount')
least_subcategories_by_value = subcategory_stats.nsmallest(5, 'Item Net Amount')

# Group by Brand and aggregate by quantity and net amount
brand_stats = df.groupby('BRAND').agg({'Qty': 'sum', 'Item Net Amount': 'sum'})

# Find the top and least selling brand by quantity and value
top_brands_by_quantity = brand_stats.nlargest(5, 'Qty')
least_brands_by_quantity = brand_stats.nsmallest(5, 'Qty')
top_brands_by_value = brand_stats.nlargest(5, 'Item Net Amount')
least_brands_by_value = brand_stats.nsmallest(5, 'Item Net Amount')

# Group by Item Name and aggregate by quantity and net amount
item_stats = df.groupby('Item Name').agg({'Qty': 'sum', 'Item Net Amount': 'sum'})

# Find the top and least selling item by quantity and value
top_items_by_quantity = item_stats.nlargest(5, 'Qty')
least_items_by_quantity = item_stats.nsmallest(5, 'Qty')
top_items_by_value = item_stats.nlargest(5, 'Item Net Amount')
least_items_by_value = item_stats.nsmallest(5, 'Item Net Amount')

# Print the results
print("Top 5 selling categories by quantity:\n", top_categories_by_quantity)
print("\nLeast 5 selling categories by quantity:\n", least_categories_by_quantity)
print("\nTop 5 selling categories by value:\n", top_categories_by_value)
print("\nLeast 5 selling categories by value:\n", least_categories_by_value)

print("\nTop 5 selling subcategories by quantity:\n", top_subcategories_by_quantity)
print("\nLeast 5 selling subcategories by quantity:\n", least_subcategories_by_quantity)
print("\nTop 5 selling subcategories by value:\n", top_subcategories_by_value)
print("\nLeast 5 selling subcategories by value:\n", least_subcategories_by_value)

print("\nTop 5 selling brands by quantity:\n", top_brands_by_quantity)
print("\nLeast 5 selling brands by quantity:\n", least_brands_by_quantity)
print("\nTop 5 selling brands by value:\n", top_brands_by_value)
print("\nLeast 5 selling brands by value:\n", least_brands_by_value)

print("\nTop 5 selling items by quantity:\n", top_items_by_quantity)
print("\nLeast 5 selling items by quantity:\n", least_items_by_quantity)
print("\nTop 5 selling items by value:\n", top_items_by_value)
print("\nLeast 5 selling items by value:\n", least_items_by_value)
# Out:
# Top 5 selling categories by quantity:
#                                    Qty  Item Net Amount
# MAIN CATEGORY
# TRISHIKA GROCERY              1697.35         87360.55
# BISCUITS & BAKERY             1594.00         31300.15
# BATHING SOAP LIQ & SANITIZER   875.00         37844.95
# READY TO EAT/INSTANT FOOD      773.00         21052.90
# FARSAN CHIKKI SWEETS           625.00         25121.32
#
# Least 5 selling categories by quantity:
#                      Qty  Item Net Amount
# MAIN CATEGORY
# BAGS&PURSES         1.0           166.00
# NONE                2.0            66.50
# APPLIANCES          3.0          2582.45
# CARRY BAG           4.0            40.00
# BATTERIES & OTHERS  6.0            85.50
#
# Top 5 selling categories by value:
#                                    Qty  Item Net Amount
# MAIN CATEGORY
# TRISHIKA GROCERY              1697.35         87360.55
# OIL & GHEE                     351.00         48386.38
# ...

# %%
import pandas as pd

# Load your Excel sheet into a DataFrame
excel_file_path = "E:\Downloads\Chintan lunawad sales category.xlsx"
sheet="Sheet 1"
df = pd.read_excel(excel_file_path, sheet_name=sheet)

# Group by Category and aggregate by quantity and net amount
category_stats = df.groupby('Predicted Category').agg({'Total Sold Qty': 'sum', 'Sale Amount AfterTax': 'sum'})

# Find the top and least selling category by quantity and value
top_categories_by_quantity = category_stats.nlargest(5, 'Total Sold Qty')
least_categories_by_quantity = category_stats.nsmallest(5, 'Total Sold Qty')
top_categories_by_value = category_stats.nlargest(5, 'Sale Amount AfterTax')
least_categories_by_value = category_stats.nsmallest(5, 'Sale Amount AfterTax')

# Group by Subcategory and aggregate by quantity and net amount
subcategory_stats = df.groupby('ITEM TYPE').agg({'Total Sold Qty': 'sum', 'Sale Amount AfterTax': 'sum'})

# Find the top and least selling subcategory by quantity and value
top_subcategories_by_quantity = subcategory_stats.nlargest(5, 'Total Sold Qty')
least_subcategories_by_quantity = subcategory_stats.nsmallest(5, 'Total Sold Qty')
top_subcategories_by_value = subcategory_stats.nlargest(5, 'Sale Amount AfterTax')
least_subcategories_by_value = subcategory_stats.nsmallest(5, 'Sale Amount AfterTax')

# Group by Brand and aggregate by quantity and net amount
brand_stats = df.groupby('BRAND').agg({'Total Sold Qty': 'sum', 'Sale Amount AfterTax': 'sum'})

# Find the top and least selling brand by quantity and value
top_brands_by_quantity = brand_stats.nlargest(5, 'Total Sold Qty')
least_brands_by_quantity = brand_stats.nsmallest(5, 'Total Sold Qty')
top_brands_by_value = brand_stats.nlargest(5, 'Sale Amount AfterTax')
least_brands_by_value = brand_stats.nsmallest(5, 'Sale Amount AfterTax')

# Group by Item Name and aggregate by quantity and net amount
item_stats = df.groupby('Item Name').agg({'Total Sold Qty': 'sum', 'Sale Amount AfterTax': 'sum'})

# Find the top and least selling item by quantity and value
top_items_by_quantity = item_stats.nlargest(5, 'Total Sold Qty')
least_items_by_quantity = item_stats.nsmallest(5, 'Total Sold Qty')
top_items_by_value = item_stats.nlargest(5, 'Sale Amount AfterTax')
least_items_by_value = item_stats.nsmallest(5, 'Sale Amount AfterTax')

# Print the results
print("Top 5 selling categories by quantity:\n", top_categories_by_quantity)
print("\nLeast 5 selling categories by quantity:\n", least_categories_by_quantity)
print("\nTop 5 selling categories by value:\n", top_categories_by_value)
print("\nLeast 5 selling categories by value:\n", least_categories_by_value)

print("\nTop 5 selling subcategories by quantity:\n", top_subcategories_by_quantity)
print("\nLeast 5 selling subcategories by quantity:\n", least_subcategories_by_quantity)
print("\nTop 5 selling subcategories by value:\n", top_subcategories_by_value)
print("\nLeast 5 selling subcategories by value:\n", least_subcategories_by_value)

print("\nTop 5 selling brands by quantity:\n", top_brands_by_quantity)
print("\nLeast 5 selling brands by quantity:\n", least_brands_by_quantity)
print("\nTop 5 selling brands by value:\n", top_brands_by_value)
print("\nLeast 5 selling brands by value:\n", least_brands_by_value)

print("\nTop 5 selling items by quantity:\n", top_items_by_quantity)
print("\nLeast 5 selling items by quantity:\n", least_items_by_quantity)
print("\nTop 5 selling items by value:\n", top_items_by_value)
print("\nLeast 5 selling items by value:\n", least_items_by_value)
# Out:
# Top 5 selling categories by quantity:
#                              Total Sold Qty  Sale Amount AfterTax
# Predicted Category
# Detergent/Washing Aids              693.00              31262.70
# Chocolates/Confectionaries          530.00               7143.71
# Hair Care                           527.00              12460.12
# Biscuits/Bakery Products            446.00              14815.05
# Grocery                             284.04              20333.25
#
# Least 5 selling categories by quantity:
#                                       Total Sold Qty  Sale Amount AfterTax
# Predicted Category
# Cold Drink/Juices/Drinks                        2.0                  99.0
# MOSQUITO REPELLENTS AND PESTICIDES              2.0                 177.0
# Electronics                                     5.0                  60.0
# Shaving Care Products                           9.0                 237.0
# Baby Foods And Health Foods/ Drinks            12.0                1502.0
#
# ...

# %%
category_keywords = {
 'Baby Foods And Health Foods/ Drinks': ['BabyFood', 'Health', 'cereal','cornflakes','oats','museli'],
 'Cosmetics': ['Skin', 'cosmetic', 'skincream', 'beauty','baby','wax','lip','sunscreen','lipstick'],
 'Bath Soap/Liquids/Sanitizers': ['soap', 'shower', 'sanitizer','handwash','bodywash','facewash'],
 'Detergent/Washing Aids': ['detergent', 'bathroom', 'washroom','freshener','disinfectant','fabric','stiffener','stain','clean','sponge','scrub','broom','mop','wiper'],
 'Sanitary Napkins & Diapers': ['sanitary', 'pads', 'diapers','tampon'],
 'Shaving Care Products': ['shave', 'gillete', 'razor'],
 'Paper/Party': ['bags', 'foil', 'paper'],
 'Biscuits/Bakery Products': ['biscuit', 'bread', 'cake','cookies','wafer','rusk','toast'],
 'Chocolates And Confectionaries': ['candy', 'lollipop', 'jelly','chewing'],
 'Cold Drink/Juices/Drinks': ['juice', 'milkshake', 'crush','pulp','syrup','squash','cola','pepsi','drink'],
 'Deo/Talcum/Perfume': ['deo', 'talc', 'perfume','rollon'],
 'Hygiene': ['condom', 'intimate', 'nail'],
 'Dairy Products': ['dairy', 'dahi','lassi','shrikhand'],
 'Dental Care': ['dental', 'oral', 'floss','toothbrush','toothcare','toothpaste','tooth','mouthwash','tongue'],
 'Hair Care': ['shampoo', 'conditioner'],
 'General Merchandise': ['apparel', 'electric', 'plastic'],
 'Dryfruits': ['dryfruit', 'dates', 'badam','ajeer','kaju'],
 'Ready To Eat/Instant Food': ['instant', 'ready', 'noodles','pasta','soup'],
 'Farshan/Chikki/Mithai': ['namkeen', 'chikki', 'mithai','chips','farsan'],
 'Grocery': ['atta', 'flour', 'dal','grains','vegetables','rice','wheat'],
 'Upwas Special': ['upwas', 'farali'],
 'Frozen Foods': ['frozen', 'icecream', 'nuggets'],
 'Pooja Items': ['agarbatti', 'pooja', 'dhoop'],
 'Ghee/Vanaspati/Oils': ['ghee', 'oil', 'vanaspati'],
 'Sugar/Salt': ['jaggery', 'salt', 'sugar'],
 'Masala And Spices': ['masala', 'spice', 'mukhwas','paste','puree'],
 'Jams/Ketchups/Spreads': ['essence', 'jam', 'sauce','chutney','ketchup','spread','vinegar','mayonnaise'],
 'Others': ['medicated', 'acidity'],
 'Mosquito Repellents And Pesticides': ['insect', 'pesticide', 'mosquito','repellent','rat'],
 'Papad/Pickles': ['papad', 'pickle', 'achaar'],
 'Shoe Care Products': ['shoe', 'boot', 'polish'],
 'Stationery': ['stationary', 'pen', 'book'],
 'Tea/Coffee': ['Tea', 'coffee', 'teabag']
}

# %%
import pandas as pd
import joblib
from fuzzywuzzy import process
import spacy
import math
import re

# Load necessary models and data
nlp = spacy.load('en_core_web_md')
df = pd.read_csv('E:/Downloads/Merger - Sheet5 (2).csv')
brands = df['BRAND'].unique()
products = df['PRODUCT'].unique()
category_names = df['CATEGORY'].unique()
# common_terms = ["GM", "KG", "ML", "L", "PACK", "BOX", "BOTTLE", "CAN", "REFILL"]
# expanded_terms = list(products) + common_terms
brand_vectors = {brand: nlp(brand).vector for brand in brands}
category_model = joblib.load("new_svc_best_model.pkl")
category_encoder = joblib.load("new_category_encoder.pkl")

# ... [Keep all the defined functions from the first code snippet here] ...
# Function to preprocess text
def preprocess_text(texts):
    return [re.sub(r'[^A-Za-z]', ' ', text.lower()) if isinstance(text, str) else text for text in texts]

# Load the category prediction model and encoder 
category_model = joblib.load("new_svc_best_model.pkl")
category_encoder = joblib.load("new_category_encoder.pkl")

# Dictionary to store default subcategories for categories with only one subcategory
default_subcategories = {
"Dryfruits": "Dry Fruits",
"Pooja Items": "Pooja Items",
"Shaving Care Products": "Shaving Care Products",
"Shoe Care Products": "Shoe Care Products",
"Stationery": "Stationery",
"Upwas Special": "Upwas Food"
}

# Function to predict main category using fuzzy matching or SVM model
# Corrected function to predict main category using fuzzy matching or SVM model
def predict_main_category(description, svc_model, encoder, category_names, fuzzy_match_threshold=90):
    # Preprocess the description
    processed_description = preprocess_text([description])[0]

    # Attempt fuzzy matching with the category names
    matched_category = None
    for word in processed_description.split():
        closest_match, score = process.extractOne(word, category_names)
        if score >= fuzzy_match_threshold:
            matched_category = closest_match
            break

    if matched_category:
        return matched_category
    else:
        model_prediction = svc_model.predict([processed_description])
        decoded_prediction = encoder.inverse_transform(model_prediction)[0]
        return decoded_prediction

# Function to predict subcategory
def predict_subcategory(description, main_category):
    # If the main category has a default subcategory, return it
    if main_category in default_subcategories:
        return default_subcategories[main_category]
    
    # Otherwise, proceed with the model prediction
    safe_filename = main_category.replace(" ", "_").replace("/", "_and_")
    model_path = safe_filename + "_model.pkl"
    encoder_path = safe_filename + "_encoder.pkl"
    vectorizer_path = safe_filename + "_vectorizer.pkl"
    
    model = joblib.load(model_path)
    encoder = joblib.load(encoder_path)
    vectorizer = joblib.load(vectorizer_path)
    
    processed_description = preprocess_text([description])[0]
    vectorized_description = vectorizer.transform([processed_description])
    encoded_prediction = model.predict(vectorized_description)
    return encoder.inverse_transform(encoded_prediction)[0]

# Load the Excel data
excel_file_path = "E:\Downloads\Chintan lunawad sales category.xlsx"
sheet = "Sheet 1"
sales_data = pd.read_excel(excel_file_path, sheet_name=sheet)

# Predict 'CATEGORY' and 'SUBCATEGORY' for each row and add them as new columns
predicted_categories = []
predicted_subcategories = []

for _, row in sales_data.iterrows():
    description = row['ITEM TYPE']
    main_category = predict_main_category(description, category_model, category_encoder, category_names)
    subcategory = predict_subcategory(description, main_category)
    predicted_categories.append(main_category)
    predicted_subcategories.append(subcategory)

sales_data['Predicted Category'] = predicted_categories
sales_data['Predicted Subcategory'] = predicted_subcategories

# ... [Now add the entire second code snippet to compute the required statistics] ...
# Group by Category and aggregate by quantity and net amount
# Group by Category and aggregate by quantity and net amount
category_stats = sales_data.groupby('Predicted Category').agg({'Total Sold Qty': 'sum', 'Sale Amount AfterTax': 'sum'})

# Find the top and least selling category by quantity and value
top_categories_by_quantity = category_stats.nlargest(5, 'Total Sold Qty')
least_categories_by_quantity = category_stats.nsmallest(5, 'Total Sold Qty')
top_categories_by_value = category_stats.nlargest(5, 'Sale Amount AfterTax')
least_categories_by_value = category_stats.nsmallest(5, 'Sale Amount AfterTax')

# Group by Subcategory and aggregate by quantity and net amount
subcategory_stats = sales_data.groupby('Predicted Subcategory').agg({'Total Sold Qty': 'sum', 'Sale Amount AfterTax': 'sum'})

# Find the top and least selling subcategory by quantity and value
top_subcategories_by_quantity = subcategory_stats.nlargest(5, 'Total Sold Qty')
least_subcategories_by_quantity = subcategory_stats.nsmallest(5, 'Total Sold Qty')
top_subcategories_by_value = subcategory_stats.nlargest(5, 'Sale Amount AfterTax')
least_subcategories_by_value = subcategory_stats.nsmallest(5, 'Sale Amount AfterTax')

# Group by Brand and aggregate by quantity and net amount
brand_stats = sales_data.groupby('BRAND').agg({'Total Sold Qty': 'sum', 'Sale Amount AfterTax': 'sum'})

# Find the top and least selling brand by quantity and value
top_brands_by_quantity = brand_stats.nlargest(5, 'Total Sold Qty')
least_brands_by_quantity = brand_stats.nsmallest(5, 'Total Sold Qty')
top_brands_by_value = brand_stats.nlargest(5, 'Sale Amount AfterTax')
least_brands_by_value = brand_stats.nsmallest(5, 'Sale Amount AfterTax')

# Group by Item Name and aggregate by quantity and net amount
item_stats = sales_data.groupby('Item Name').agg({'Total Sold Qty': 'sum', 'Sale Amount AfterTax': 'sum'})

# Find the top and least selling item by quantity and value
top_items_by_quantity = item_stats.nlargest(5, 'Total Sold Qty')
least_items_by_quantity = item_stats.nsmallest(5, 'Total Sold Qty')
top_items_by_value = item_stats.nlargest(5, 'Sale Amount AfterTax')
least_items_by_value = item_stats.nsmallest(5, 'Sale Amount AfterTax')

# Print the results
print("Top 5 selling categories by quantity:\n", top_categories_by_quantity)
print("\nLeast 5 selling categories by quantity:\n", least_categories_by_quantity)
print("\nTop 5 selling categories by value:\n", top_categories_by_value)
print("\nLeast 5 selling categories by value:\n", least_categories_by_value)

print("\nTop 5 selling subcategories by quantity:\n", top_subcategories_by_quantity)
print("\nLeast 5 selling subcategories by quantity:\n", least_subcategories_by_quantity)
print("\nTop 5 selling subcategories by value:\n", top_subcategories_by_value)
print("\nLeast 5 selling subcategories by value:\n", least_subcategories_by_value)

print("\nTop 5 selling brands by quantity:\n", top_brands_by_quantity)
print("\nLeast 5 selling brands by quantity:\n", least_brands_by_quantity)
print("\nTop 5 selling brands by value:\n", top_brands_by_value)
print("\nLeast 5 selling brands by value:\n", least_brands_by_value)

print("\nTop 5 selling items by quantity:\n", top_items_by_quantity)
print("\nLeast 5 selling items by quantity:\n", least_items_by_quantity)
print("\nTop 5 selling items by value:\n", top_items_by_value)
print("\nLeast 5 selling items by value:\n", least_items_by_value)
# Out:
# Top 5 selling categories by quantity:
#                                  Total Sold Qty  Sale Amount AfterTax
# Predicted Category
# Detergent/Washing Aids                   635.0              29840.36
# Hair Care                                527.0              12505.12
# General Merchandise                      490.0              35643.00
# Biscuits/Bakery Products                 413.0              12904.05
# Chocolates And Confectionaries           411.0               5239.00
#
# Least 5 selling categories by quantity:
#                                        Total Sold Qty  Sale Amount AfterTax
# Predicted Category
# Hygiene                                          2.0                 50.00
# Baby Foods And Health Foods/ Drinks              6.0                587.00
# Mosquito Repellents And  Pesticides              6.0                302.00
# Shaving Care Products                            9.0                520.00
# ...

# %%
import pandas as pd
import joblib
from fuzzywuzzy import process
import spacy
import math
import re

# Load necessary models and data
nlp = spacy.load('en_core_web_md')
df = pd.read_csv('E:/Downloads/Merger - Sheet5 (2).csv')
brands = df['BRAND'].unique()
products = df['PRODUCT'].unique()
category_names = df['CATEGORY'].unique()
# common_terms = ["GM", "KG", "ML", "L", "PACK", "BOX", "BOTTLE", "CAN", "REFILL"]
# expanded_terms = list(products) + common_terms
brand_vectors = {brand: nlp(brand).vector for brand in brands}
category_model = joblib.load("new_svc_best_model.pkl")
category_encoder = joblib.load("new_category_encoder.pkl")

# ... [Keep all the defined functions from the first code snippet here] ...
# Function to preprocess text
def preprocess_text(texts):
    return [re.sub(r'[^A-Za-z]', ' ', text.lower()) if isinstance(text, str) else text for text in texts]

# Load the category prediction model and encoder 
category_model = joblib.load("new_svc_best_model.pkl")
category_encoder = joblib.load("new_category_encoder.pkl")

# Dictionary to store default subcategories for categories with only one subcategory
default_subcategories = {
"Dryfruits": "Dry Fruits",
"Pooja Items": "Pooja Items",
"Shaving Care Products": "Shaving Care Products",
"Shoe Care Products": "Shoe Care Products",
"Stationery": "Stationery",
"Upwas Special": "Upwas Food"
}

# Function to predict main category using fuzzy matching or SVM model
# Corrected function to predict main category using fuzzy matching or SVM model
def predict_main_category(description, svc_model, encoder, category_names, fuzzy_match_threshold=90):
    # Preprocess the description
    processed_description = preprocess_text([description])[0]

    # Attempt fuzzy matching with the category names
    matched_category = None
    for word in processed_description.split():
        closest_match, score = process.extractOne(word, category_names)
        if score >= fuzzy_match_threshold:
            matched_category = closest_match
            break

    if matched_category:
        return matched_category
    else:
        model_prediction = svc_model.predict([processed_description])
        decoded_prediction = encoder.inverse_transform(model_prediction)[0]
        return decoded_prediction

# Function to predict subcategory
def predict_subcategory(description, main_category):
    # If the main category has a default subcategory, return it
    if main_category in default_subcategories:
        return default_subcategories[main_category]
    
    # Otherwise, proceed with the model prediction
    safe_filename = main_category.replace(" ", "_").replace("/", "_and_")
    model_path = safe_filename + "_model.pkl"
    encoder_path = safe_filename + "_encoder.pkl"
    vectorizer_path = safe_filename + "_vectorizer.pkl"
    
    model = joblib.load(model_path)
    encoder = joblib.load(encoder_path)
    vectorizer = joblib.load(vectorizer_path)
    
    processed_description = preprocess_text([description])[0]
    vectorized_description = vectorizer.transform([processed_description])
    encoded_prediction = model.predict(vectorized_description)
    return encoder.inverse_transform(encoded_prediction)[0]

# Load the Excel data
excel_file_path = "E:\Downloads\Chintan lunawad sales category.xlsx"
sheet = "Sheet 1"
sales_data = pd.read_excel(excel_file_path, sheet_name=sheet)

# Predict 'CATEGORY' and 'SUBCATEGORY' for each row and add them as new columns
predicted_categories = []
predicted_subcategories = []

for _, row in sales_data.iterrows():
    description = row['ITEM TYPE']
    main_category = predict_main_category(description, category_model, category_encoder, category_names)
    subcategory = predict_subcategory(description, main_category)
    predicted_categories.append(main_category)
    predicted_subcategories.append(subcategory)
    print(description, main_category, subcategory)

sales_data['Predicted Category'] = predicted_categories
sales_data['Predicted Subcategory'] = predicted_subcategories
# Out:
#  COFFEE Tea/Coffee Coffee
#  BOURN VITA Cosmetics Skin Care
#  BOURN VITA Cosmetics Skin Care
#  BOURN VITA Cosmetics Skin Care
#  BOURN VITA Cosmetics Skin Care
#  CHYAWANPRASH Baby Foods And Health Foods/ Drinks Health Foods
#  ENO Others Acidity Reliever
#  ENO Others Acidity Reliever
#  ENO Others Acidity Reliever
#  ENO Others Acidity Reliever
#  ENO Others Acidity Reliever
#  ENO Others Acidity Reliever
#  ENO Others Acidity Reliever
#  HORLICKS Baby Foods And Health Foods/ Drinks Health Drink
#  GREEN TEA Tea/Coffee Tea
#  MANCHURIAN FLOUR Grocery Atta
#  SYRUP Cold Drink/Juices/Drinks Others
#  COFFEE Tea/Coffee Coffee
#  COFFEE Tea/Coffee Coffee
#  COFFEE Tea/Coffee Coffee
#  COFFEE Tea/Coffee Coffee
#  COFFEE Tea/Coffee Coffee
#  NA General Merchandise Plasticware & Kitchen Appliances
#  TEA Tea/Coffee Tea
#  TEA Tea/Coffee Tea
#  TEA Tea/Coffee Tea
#  TEA Tea/Coffee Tea
#  TEA Tea/Coffee Tea
#  TEA Tea/Coffee Tea
#  TEA Tea/Coffee Tea
#  TEA Tea/Coffee Tea
# ...

# %%
import pandas as pd
import joblib
import re
from fuzzywuzzy import process

# Function to preprocess text
def preprocess_text(texts):
    return [re.sub(r'[^A-Za-z]', ' ', text.lower()) if isinstance(text, str) else text for text in texts]

# Function to predict categories from a list of product descriptions
def predict_categories(product_descriptions, svc_model, encoder, category_names, fuzzy_match_threshold=90):
    predictions = []

    for description in product_descriptions:
        # Preprocess the description
        processed_description = preprocess_text([description])[0]

        # Attempt to match with category-specific words
        matched_category = None
        for word in processed_description.split():
            for category, keywords in category_keywords.items():
                if word in keywords:
                    matched_category = category
                    break
            if matched_category:
                break

        if matched_category:
            # If a match is found, we use it as the prediction
            predictions.append(matched_category)
            print(f"Description: {description}\nPredicted Category (matched): {matched_category}\n")
        else:
            # If no match is found, we proceed to use the model for prediction
            model_prediction = svc_model.predict([processed_description])
            decoded_prediction = encoder.inverse_transform(model_prediction)[0]
            predictions.append(decoded_prediction)
            print(f"Description: {description}\nPredicted Category (model): {decoded_prediction}\n")

    return predictions

# Function to extract product descriptions from an Excel sheet
def extract_descriptions_from_excel(excel_file, sheet_name, column_name):
    try:
        input_data = pd.read_excel(excel_file, sheet_name=sheet_name)
        if column_name in input_data.columns:
            return input_data[column_name].tolist()
        else:
            print(f"The column '{column_name}' does not exist in the Excel sheet.")
            return []
    except Exception as e:
        print(f"An error occurred while reading the Excel file: {e}")
        return []

# Load the trained model and the label encoder
svc_model = joblib.load('new_svc_best_model.pkl')
encoder = joblib.load('new_category_encoder.pkl')  # Adjust path if your encoder is saved elsewhere

# Extract product descriptions from another Excel sheet
excel_file_path = 'E:\Downloads\Chintan lunawad sales category.xlsx'
sheet_name = 'Sheet 1'  # Modify to your sheet name
column_name = 'ITEM TYPE'  # Modify to the column name containing descriptions
product_descriptions = extract_descriptions_from_excel(excel_file_path, sheet_name, column_name)

if product_descriptions:
    # Extract unique category names from the 'CATEGORY' column
    #category_names = data['CATEGORY'].unique().tolist()
    category_names = [name.lower() if isinstance(name, str) else name for name in category_names]
    # Predict categories for the extracted descriptions
    predictions = predict_categories(product_descriptions, svc_model, encoder, category_names)
else:
    print("No product descriptions found in the Excel sheet.")
# Out:
# Description:  COFFEE
# Predicted Category (matched): Tea/Coffee
#
# Description:  BOURN VITA
# Predicted Category (model): Cosmetics
#
# Description:  BOURN VITA
# Predicted Category (model): Cosmetics
#
# Description:  BOURN VITA
# Predicted Category (model): Cosmetics
#
# Description:  BOURN VITA
# Predicted Category (model): Cosmetics
#
# Description:  CHYAWANPRASH
# Predicted Category (model): Baby Foods And Health Foods/ Drinks
#
# Description:  ENO
# Predicted Category (model): Others
#
# Description:  ENO
# Predicted Category (model): Others
#
# Description:  ENO
# Predicted Category (model): Others
#
# Description:  ENO
# Predicted Category (model): Others
#
# Description:  ENO
# Predicted Category (model): Others
#
# Description:  ENO
# Predicted Category (model): Others
#
# Description:  ENO
# Predicted Category (model): Others
#
# Description:  HORLICKS
# Predicted Category (model): Baby Foods And Health Foods/ Drinks
#
# Description:  GREEN TEA
# ...

# %%
import pandas as pd
import joblib
import re
from fuzzywuzzy import process

# Function to preprocess text
def preprocess_text(texts):
    return [re.sub(r'[^A-Za-z]', ' ', text.lower()) if isinstance(text, str) else text for text in texts]

import pandas as pd
import joblib
import re
from fuzzywuzzy import process

# Function to preprocess text
def preprocess_text(texts):
    return [re.sub(r'[^A-Za-z]', ' ', text.lower()) if isinstance(text, str) else text for text in texts]

def compute_cosine_similarity(vec_a, vec_b):
    """Compute cosine similarity between two vectors."""
    dot_product = sum(p*q for p,q in zip(vec_a, vec_b))
    magnitude = math.sqrt(sum([val**2 for val in vec_a])) * math.sqrt(sum([val**2 for val in vec_b]))
    if not magnitude:
        return 0
    return dot_product/magnitude

def predict_categories(product_descriptions, svc_model, encoder, category_names, similarity_threshold=0.7):
    predictions = []
    
    # Compute embeddings for category names
    category_embeddings = {category: nlp(category).vector for category in category_names}

    for description in product_descriptions:
        # Preprocess the description
        processed_description = preprocess_text([description])[0]

        # Compute the embedding for the processed description
        description_embedding = nlp(processed_description).vector

        # Compute the cosine similarity with each category
        similarities = {category: compute_cosine_similarity(description_embedding, vector) for category, vector in category_embeddings.items()}
        
        # Get the category with the highest similarity
        best_match_category = max(similarities, key=similarities.get)

        if similarities[best_match_category] > similarity_threshold:
            predictions.append(best_match_category)
            print(f"Description: {description}\nPredicted Category (context-aware matching): {best_match_category}\n")
        else:
            # If no match is found based on similarity, we proceed to use the model for prediction
            model_prediction = svc_model.predict([processed_description])
            decoded_prediction = encoder.inverse_transform(model_prediction)[0]
            predictions.append(decoded_prediction)
            print(f"Description: {description}\nPredicted Category (model): {decoded_prediction}\n")

    return predictions


# Function to extract product descriptions from an Excel sheet
def extract_descriptions_from_excel(excel_file, sheet_name, column_name):
    try:
        input_data = pd.read_excel(excel_file, sheet_name=sheet_name)
        if column_name in input_data.columns:
            return input_data[column_name].tolist()
        else:
            print(f"The column '{column_name}' does not exist in the Excel sheet.")
            return []
    except Exception as e:
        print(f"An error occurred while reading the Excel file: {e}")
        return []

# Load the trained model and the label encoder
svc_model = joblib.load('new_svc_best_model.pkl')
encoder = joblib.load('new_category_encoder.pkl')  # Adjust path if your encoder is saved elsewhere

# Extract product descriptions from another Excel sheet
excel_file_path = 'E:\Downloads\Chintan lunawad sales category.xlsx'
sheet_name = 'Sheet 1'  # Modify to your sheet name
column_name = 'ITEM TYPE'  # Modify to the column name containing descriptions
product_descriptions = extract_descriptions_from_excel(excel_file_path, sheet_name, column_name)

if product_descriptions:
    # Extract unique category names from the 'CATEGORY' column
    #category_names = data['CATEGORY'].unique().tolist()
    category_names = [name.lower() if isinstance(name, str) else name for name in category_names]
    # Predict categories for the extracted descriptions
    predictions = predict_categories(product_descriptions, svc_model, encoder, category_names)
else:
    print("No product descriptions found in the Excel sheet.")


# Function to extract product descriptions from an Excel sheet
def extract_descriptions_from_excel(excel_file, sheet_name, column_name):
    try:
        input_data = pd.read_excel(excel_file, sheet_name=sheet_name)
        if column_name in input_data.columns:
            return input_data[column_name].tolist()
        else:
            print(f"The column '{column_name}' does not exist in the Excel sheet.")
            return []
    except Exception as e:
        print(f"An error occurred while reading the Excel file: {e}")
        return []

# Load the trained model and the label encoder
svc_model = joblib.load('new_svc_best_model.pkl')
encoder = joblib.load('new_category_encoder.pkl')  # Adjust path if your encoder is saved elsewhere

# Extract product descriptions from another Excel sheet
excel_file_path = 'E:\Downloads\Chintan lunawad sales category.xlsx'
sheet_name = 'Sheet 1'  # Modify to your sheet name
column_name = 'ITEM TYPE'  # Modify to the column name containing descriptions
product_descriptions = extract_descriptions_from_excel(excel_file_path, sheet_name, column_name)

if product_descriptions:
    # Extract unique category names from the 'CATEGORY' column
    #category_names = data['CATEGORY'].unique().tolist()
    category_names = [name.lower() if isinstance(name, str) else name for name in category_names]
    # Predict categories for the extracted descriptions
    predictions = predict_categories(product_descriptions, svc_model, encoder, category_names)
else:
    print("No product descriptions found in the Excel sheet.")
# Out:
# Description:  COFFEE
# Predicted Category (model): Tea/Coffee
#
# Description:  BOURN VITA
# Predicted Category (model): Cosmetics
#
# Description:  BOURN VITA
# Predicted Category (model): Cosmetics
#
# Description:  BOURN VITA
# Predicted Category (model): Cosmetics
#
# Description:  BOURN VITA
# Predicted Category (model): Cosmetics
#
# Description:  CHYAWANPRASH
# Predicted Category (model): Baby Foods And Health Foods/ Drinks
#
# Description:  ENO
# Predicted Category (model): Others
#
# Description:  ENO
# Predicted Category (model): Others
#
# Description:  ENO
# Predicted Category (model): Others
#
# Description:  ENO
# Predicted Category (model): Others
#
# Description:  ENO
# Predicted Category (model): Others
#
# Description:  ENO
# Predicted Category (model): Others
#
# Description:  ENO
# Predicted Category (model): Others
#
# Description:  HORLICKS
# Predicted Category (model): Baby Foods And Health Foods/ Drinks
#
# Description:  GREEN TEA
# ...

# %%
category_names = df['CATEGORY'].unique()
category_names
# Out:
# array(['Baby Foods And Health Foods/ Drinks', 'Cosmetics',
#        'Bath Soap/Liquids/Sanitizers', 'Detergent/Washing Aids',
#        'Sanitary Napkins & Diapers', 'Shaving Care Products',
#        'Paper/Party Products', 'Biscuits/Bakery Products',
#        'Chocolates And Confectionaries', 'Cold Drink/Juices/Drinks',
#        'Deo/Talcum/Perfume', 'Hygiene', 'Dairy Products', 'Dental Care',
#        'Hair Care', 'General Merchandise', 'Dryfruits',
#        'Ready To Eat/Instant Food', 'Farshan/Chikki/Mithai', 'Grocery',
#        'Upwas Special', 'Frozen Foods', 'Pooja Items',
#        'Ghee/Vanaspati/Oils', 'Sugar/Salt', 'Masala And Spices',
#        'Jams/Ketchups/Spreads', 'Others',
#        'Mosquito Repellents And  Pesticides ', 'Papad/Pickles',
#        'Shoe Care Products', 'Stationery', 'Tea/Coffee'], dtype=object)
